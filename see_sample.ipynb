# %% [markdown]
# ### Sample for SEE

# %% [markdown]
# Using databases 'KA_MLA_2018_to_2023' and 'KA2023_Winners' to practice.

# %%
import pandas as pd
import os
import sqlite3 as lite
from glob import glob

dbpath = 'see_sample.sqlite'
con = lite.connect(dbpath)
cursor = con.cursor()

# %%
con.execute('PRAGMA foreign_keys = ON;')

# %% [markdown]
# 1. Creating lookup table KA_Constituencies

# %%
data1 = pd.read_csv('/Users/reethu/coding/college/DBMS/Databases/KA_MLA_2018_to_2023.csv')
data1
# Out:
#      AC_Num      Constituency                    MLA_Name Party
# 0         1           Nippani  Shashikala Annasaheb Jolle   BJP
# 1         2  Chikkodi-Sadalga              Ganesh Hukkeri   INC
# 2         3            Athani           Mahesh Kumathalli   BJP
# 3         4            Kagwad               Srimant Patil   BJP
# 4         5           Kudachi                   P. Rajeev   BJP
# ..      ...               ...                         ...   ...
# 219     220      T Narasipura             Ashvin Kumar M.   JDS
# 220     221             Hanur                 R. Narendra   INC
# 221     222          Kollegal                   N. Mahesh   BJP
# 222     223     Chamrajanagar         C. Puttarangashetty   INC
# 223     224         Gundlupet         C.S. Niranjan Kumar   BJP
#
# [224 rows x 4 columns]

# %%
table1 = """
   CREATE TABLE KA_Constituencies(
     AC_Num INTEGER Primary Key,
     AC_Name TEXT)
"""
con.execute(table1)
con.commit()

# %%
insert_sql1 = "INSERT INTO KA_Constituencies(AC_Num, AC_Name) VALUES (?, ?)"

for index, row in data1.iterrows():
    values = (row['AC_Num'], row['Constituency'])
    cursor.execute(insert_sql1, values)
    
con.commit()
pd.read_sql("Select * from KA_Constituencies", con)
# Out:
#      AC_Num           AC_Name
# 0         1           Nippani
# 1         2  Chikkodi-Sadalga
# 2         3            Athani
# 3         4            Kagwad
# 4         5           Kudachi
# ..      ...               ...
# 219     220      T Narasipura
# 220     221             Hanur
# 221     222          Kollegal
# 222     223     Chamrajanagar
# 223     224         Gundlupet
#
# [224 rows x 2 columns]

# %% [markdown]
# 2. Creating table MLA_2018

# %%
table2 = """ CREATE TABLE MLA_2018(
        AC_Num INTEGER Primary Key,
        MLA_Name Text,
        Party Text,
        FOREIGN KEY (AC_Num) REFERENCES KA_Constituencies(AC_Num))
      """
con.execute(table2)
con.commit()
pd.read_sql("PRAGMA table_info(MLA_2018)", con)
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0    AC_Num  INTEGER        0       None   1
# 1    1  MLA_Name     TEXT        0       None   0
# 2    2     Party     TEXT        0       None   0

# %%
insert_sql2 = "INSERT INTO MLA_2018(AC_Num, MLA_Name, Party) VALUES (?, ?, ?)"

for index, row in data1.iterrows():
    values = (row['AC_Num'], row['MLA_Name'], row['Party'])
    cursor.execute(insert_sql2, values)
    
con.commit()

# %%
pd.read_sql("Select * from MLA_2018",con)
# Out:
#      AC_Num                    MLA_Name Party
# 0         1  Shashikala Annasaheb Jolle   BJP
# 1         2              Ganesh Hukkeri   INC
# 2         3           Mahesh Kumathalli   BJP
# 3         4               Srimant Patil   BJP
# 4         5                   P. Rajeev   BJP
# ..      ...                         ...   ...
# 219     220             Ashvin Kumar M.   JDS
# 220     221                 R. Narendra   INC
# 221     222                   N. Mahesh   BJP
# 222     223         C. Puttarangashetty   INC
# 223     224         C.S. Niranjan Kumar   BJP
#
# [224 rows x 3 columns]

# %% [markdown]
# 3. Creating table MLA_2023

# %%
data2 = pd.read_excel('/Users/reethu/coding/college/DBMS/Databases/KA2023_Winners.xlsx')
data2
# Out:
#     Sl No.  Constituency Name                        Winners     Party
# 0        1            Nippani     Jolle Shashikala Annasaheb       BJP
# 1        2   Chikkodi-Sadalga         Ganesh Prakash Hukkeri  Congress
# 2        3             Athani                  Laxman Savadi  Congress
# 3        4             Kagwad      Bharamgouda Alagouda Kage  Congress
# 4        5       Kudachi (SC)  Mahendra Kallappa Tammannavar  Congress
# ..     ...                ...                            ...       ...
# 219    220  T. Narasipur (SC)             Dr H C Mahadevappa  Congress
# 220    221              Hanur                  M R Manjunath     JD(S)
# 221    222      Kollegal (SC)              A R Krishnamurthy  Congress
# 222    223     Chamarajanagar             C Puttarangashetty  Congress
# 223    224          Gundlupet              H M Ganesh Prasad  Congress
#
# [224 rows x 4 columns]

# %%
table3 = """ CREATE TABLE MLA_2023(
        AC_Num INTEGER Primary Key,
        MLA_Name Text,
        Party Text,
        FOREIGN KEY (AC_Num) REFERENCES KA_Constituencies(AC_Num))
      """
con.execute(table3)
con.commit()
pd.read_sql("PRAGMA table_info(MLA_2023)", con)
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0    AC_Num  INTEGER        0       None   1
# 1    1  MLA_Name     TEXT        0       None   0
# 2    2     Party     TEXT        0       None   0

# %%
data2.to_sql('MLA_2023_temp',con, if_exists='replace',index=False)
# Out:
# 224

# %%
pd.set_option('display.max_rows', None)
pd.read_sql("Select * from MLA_2023_temp",con)
# Out:
#     Sl No.        Constituency Name  \
# 0        1                  Nippani
# 1        2         Chikkodi-Sadalga
# 2        3                   Athani
# 3        4                   Kagwad
# 4        5             Kudachi (SC)
# 5        6              Raybag (SC)
# 6        7                  Hukkeri
# 7        8                 Arabhavi
# 8        9                    Gokak
# 9       10         Yemkanmardi (ST)
# 10      11            Belgaum Uttar
# 11      12          Belgaum Dakshin
# 12      13            Belgaum Rural
# 13      14                 Khanapur
# 14      15                   Kittur
# 15      16               Bailhongal
# 16      17       Saundatti Yellamma
# 17      18                  Ramdurg
# 18      19              Mudhol (SC)
# 19      20                   Terdal
# 20      21                Jamkhandi
# 21      22                    Bilgi
# 22      23                   Badami
# 23      24                 Bagalkot
# 24      25                  Hungund
# 25      26               Muddebihal
# 26      27           Devar Hippargi
# 27      28        Basavana Bagevadi
# 28      29              Babaleshwar
# 29      30             Bijapur City
# 30      31            Nagathan (SC)
# 31      32                     Indi
# 32      33                  Sindagi
# 33      34                 Afzalpur
# 34      35                  Jewargi
# 35      36            Shorapur (ST)
# 36      37                 Shahapur
# 37      38                   Yadgir
# 38      39                Gurmitkal
# 39      40           Chittapur (SC)
# 40      41                    Sedam
# 41      42           Chincholi (SC)
# 42      43      Gulbarga Rural (SC)
# 43      44         Gulbarga Dakshin
# 44      45           Gulbarga Uttar
# 45      46                    Aland
# 46      47             Basavakalyan
# 47      48                 Homnabad
# 48      49              Bidar South
# 49      50                    Bidar
# 50      51                   Bhalki
# 51      52               Aurad (SC)
# 52      53       Raichur Rural (ST)
# 53      54                  Raichur
# 54      55               Manvi (ST)
# 55      56           Devadurga (ST)
# 56      57           Lingsugur (SC)
# 57      58                Sindhanur
# 58      59               Maski (ST)
# 59      60                 Kushtagi
# 60      61          Kanakagiri (SC)
# 61      62                Gangawati
# 62      63                 Yelburga
# 63      64                   Koppal
# 64      65          Shirahatti (SC)
# 65      66                    Gadag
# 66      67                      Ron
# 67      68                  Nargund
# 68      69                Navalgund
# 69      70                  Kundgol
# 70      71                  Dharwad
# 71      72  Hubli-Dharwad East (SC)
# 72      73    Hubli-Dharwad Central
# 73      74       Hubli-Dharwad West
# 74      75                Kalghatgi
# 75      76                  Haliyal
# 76      77                   Karwar
# 77      78                    Kumta
# 78      79                  Bhatkal
# 79      80                    Sirsi
# 80      81                 Yellapur
# 81      82                   Hangal
# 82      83                 Shiggaon
# 83      84              Haveri (SC)
# 84      85                   Byadgi
# 85      86                Hirekerur
# 86      87               Ranebennur
# 87      88           Hadagalli (SC)
# 88      89  Hagaribommanahalli (SC)
# 89      90             Vijayanagara
# 90      91              Kampli (ST)
# 91      92           Siruguppa (ST)
# 92      93       Bellary Rural (ST)
# 93      94             Bellary City
# 94      95              Sandur (ST)
# 95      96             Kudligi (ST)
# 96      97         Molakalmuru (ST)
# 97      98          Challakere (ST)
# 98      99              Chitradurga
# 99     100                  Hiriyur
# 100    101                Hosadurga
# 101    102           Holalkere (SC)
# 102    103             Jagalur (ST)
# 103    104            Harapanahalli
# 104    105                  Harihar
# 105    106         Davanagere North
# 106    107         Davanagere South
# 107    108           Mayakonda (SC)
# 108    109               Channagiri
# 109    110                  Honnali
# 110    111       Shimoga Rural (SC)
# 111    112               Bhadravati
# 112    113                  Shimoga
# 113    114              Tirthahalli
# 114    115              Shikaripura
# 115    116                    Sorab
# 116    117                    Sagar
# 117    118                  Byndoor
# 118    119                Kundapura
# 119    120                    Udupi
# 120    121                     Kapu
# 121    122                   Karkal
# 122    123                 Sringeri
# 123    124            Mudigere (SC)
# 124    125              Chikmagalur
# 125    126                 Tarikere
# 126    127                    Kadur
# 127    128         Chiknayakanhalli
# 128    129                   Tiptur
# 129    130               Turuvekere
# 130    131                  Kunigal
# 131    132              Tumkur City
# 132    133             Tumkur Rural
# 133    134          Koratagere (SC)
# 134    135                    Gubbi
# 135    136                     Sira
# 136    137            Pavagada (SC)
# 137    138                Madhugiri
# 138    139             Gauribidanur
# 139    140                Bagepalli
# 140    141           Chikkaballapur
# 141    142              Sidlaghatta
# 142    143               Chintamani
# 143    144              Srinivaspur
# 144    145            Mulbagal (SC)
# 145    146    Kolar Gold Field (SC)
# 146    147          Bangarapet (SC)
# 147    148                    Kolar
# 148    149                    Malur
# 168                           Uday B Garudachar           BJP
# 169                         Ravi Subramanya L A           BJP
# 170                                    R Ashoka           BJP
# 171                             Ramalinga Reddy      Congress
# 172                              C K Ramamurthy           BJP
# 173                                   Manjula S           BJP
# 174                              Satish Reddy M           BJP
# 175                                M Krishnappa           BJP
# 176                                  V Shivanna      Congress
# 177                    Sharath Kumar Bachegowda      Congress
# 178                               K H Muniyappa      Congress
# 179                             Dheeraj Muniraj           BJP
# 180                            Shreenivasaiah N      Congress
# 181                             H C Balakrishna      Congress
# 182                               Iqbal Hussain      Congress
# 183                              D K Shivakumar      Congress
# 184                             H D Kumaraswamy         JD(S)
# 185                           P M Narendraswamy      Congress
# 186                                   Udaya K M      Congress
# 187                         Darshan Puttannaiah  SKP-Congress
# 188                             Ravikumar Gowda      Congress
# 189                 A B Ramesha Bandisiddegowda      Congress
# 190                          N Chaluvarayaswamy      Congress
# 191                                   H T Manju         JD(S)
# 192                             C N Balakrishna         JD(S)
# 193                        K M Shivalinge Gowda      Congress
# 194                                  H K Suresh           BJP
# 195                                 H P Swaroop         JD(S)
# 196                                 H D Revanna         JD(S)
# 197                                     A Manju         JD(S)
# 198                                Cement Manju           BJP
# 199                               Harish Poonja           BJP
# 200                             Umanatha Kotian           BJP
# 201                         Dr Y Bharath Shetty           BJP
# 202                          D Vedavyasa Kamath           BJP
# 203                                   UT Khader      Congress
# 204                               Rajesh Naik U           BJP
# 205                             Ashok Kumar Rai      Congress
# 206                          Bhagirathi Murulya           BJP
# 207                             Dr Mantar Gowda      Congress
# 208                                A S Ponnanna      Congress
# 209                                 K Venkatesh      Congress
# 210                               Ravishankar D      Congress
# 211                            G D Harish Gowda         JD(S)
# 212                            Anil Chikkamadhu      Congress
# 213                      Darshan Dhruvanarayana      Congress
# 214                               G T Devegowda         JD(S)
# 215                               T S Srivathsa           BJP
# 216                              K Harish Gowda      Congress
# 217                                Tanveer Sait      Congress
# 218                                Siddaramaiah      Congress
# 219                          Dr H C Mahadevappa      Congress
# 220                               M R Manjunath         JD(S)
# 221                           A R Krishnamurthy      Congress
# 222                          C Puttarangashetty      Congress
# 223                           H M Ganesh Prasad      Congress

# %%
query1 = """UPDATE MLA_2023_temp SET "Sl No." = '170' where "Sl No." = 'BJ170' """
con.execute(query1)
con.commit()

# %%
pd.set_option('display.max_rows', None)
pd.read_sql("Select * from MLA_2023_temp",con)
# Out:
#     Sl No.        Constituency Name  \
# 0        1                  Nippani
# 1        2         Chikkodi-Sadalga
# 2        3                   Athani
# 3        4                   Kagwad
# 4        5             Kudachi (SC)
# 5        6              Raybag (SC)
# 6        7                  Hukkeri
# 7        8                 Arabhavi
# 8        9                    Gokak
# 9       10         Yemkanmardi (ST)
# 10      11            Belgaum Uttar
# 11      12          Belgaum Dakshin
# 12      13            Belgaum Rural
# 13      14                 Khanapur
# 14      15                   Kittur
# 15      16               Bailhongal
# 16      17       Saundatti Yellamma
# 17      18                  Ramdurg
# 18      19              Mudhol (SC)
# 19      20                   Terdal
# 20      21                Jamkhandi
# 130    131                  Kunigal
# 131    132              Tumkur City
# 132    133             Tumkur Rural
# 133    134          Koratagere (SC)
# 134    135                    Gubbi
# 135    136                     Sira
# 136    137            Pavagada (SC)
# 137    138                Madhugiri
# 138    139             Gauribidanur
# 139    140                Bagepalli
# 140    141           Chikkaballapur
# 141    142              Sidlaghatta
# 142    143               Chintamani
# 143    144              Srinivaspur
# 144    145            Mulbagal (SC)
# 145    146    Kolar Gold Field (SC)
# 146    147          Bangarapet (SC)
# 147    148                    Kolar
# 148    149                    Malur
# 149    150                Yelahanka
# 150    151         Krishnarajapuram
# 151    152          Byatarayanapura
# 152    153              Yeshwantpur
# 153    154      Rajarajeshwarinagar
# 154    155              Dasarahalli
# 155    156       Mahalakshmi Layout
# 156    157             Malleshwaram
# 157    158                   Hebbal
# 158    159      Pulakeshinagar (SC)
# 159    160            Sarvagnanagar
# 160    161     C V Raman Nagar (SC)
# 161    162             Shivajinagar
# 162    163             Shanti Nagar
# 163    164             Gandhi Nagar
# 164    165             Rajaji Nagar
# 165    166          Govindraj Nagar
# 166    167              Vijay Nagar
# 167    168               Chamrajpet
# 168    169                 Chickpet
# 169    170             Basavanagudi
# 170    171          Padmanabhanagar
# 171    172            B.T.M. Layout
# 172    173                Jayanagar
# 173    174        Mahadevapura (SC)
# 174    175             Bommanahalli
# 175    176          Bangalore South
# 176    177              Anekal (SC)
# 177    178                  Hoskote
# 178    179         Devanahalli (SC)
# 179    180            Doddaballapur
# 180    181         Nelamangala (SC)
# 181    182                   Magadi
# 182    183              Ramanagaram
# 183    184               Kanakapura
# 184    185              Channapatna
# 185    186           Malavalli (SC)
# 186    187                   Maddur
# 187    188                 Melukote
# 188    189                   Mandya
# 189    190         Shrirangapattana
# 190    191              Nagamangala
# 191    192           Krishnarajapet
# 192    193         Shravanabelagola
# 193    194                 Arsikere
# 194    195                    Belur
# 195    196                   Hassan
# 196    197            Holenarasipur
# 197    198                 Arkalgud
# 198    199          Sakleshpur (SC)
# 199    200              Belthangady
# 200    201               Moodabidri
# 201    202     Mangalore City North
# 202    203     Mangalore City South
# 203    204                Mangalore
# 204    205                  Bantval
# 205    206                   Puttur
# 206    207              Sullia (SC)
# 207    208                 Madikeri
# 208    209                 Virajpet
# 209    210              Piriyapatna
# 210    211        Krishnarajanagara
# 211    212                   Hunsur
# 212    213    Heggadadevankote (ST)
# 213    214           Nanjangud (SC)
# 214    215           Chamundeshwari
# 215    216              Krishnaraja
# 216    217                Chamaraja
# 217    218            Narasimharaja
# 218    219                   Varuna
# 219    220        T. Narasipur (SC)
# 220    221                    Hanur
# 221    222            Kollegal (SC)
# 222    223           Chamarajanagar
# 223    224                Gundlupet
#
#                                         Winners         Party
# 0                    Jolle Shashikala Annasaheb           BJP
# 1                        Ganesh Prakash Hukkeri      Congress
# 2                                 Laxman Savadi      Congress
# 3                     Bharamgouda Alagouda Kage      Congress
# 4                 Mahendra Kallappa Tammannavar      Congress
# 5                 Aihole Duryodhan Mahalingappa           BJP
# 6                            Katti Nikhil Umesh           BJP
# 153                                  Munirathna           BJP
# 154                                  S Muniraju           BJP
# 155                                 K Gopalaiah           BJP
# 156                       Dr C N Ashwathnarayan           BJP
# 157                                 Suresha B S      Congress
# 158                             A. C. Srinivasa      Congress
# 159                                  K J George      Congress
# 160                                     S Raghu           BJP
# 161                               Rizwan Arshad      Congress
# 162                                  N A Harris      Congress
# 163                            Dinesh Gundu Rao      Congress
# 164                              S Suresh Kumar           BJP
# 165                                Priyakrishna      Congress
# 166                                M Krishnappa      Congress
# 167                        BZ Zameer Ahmed Khan      Congress
# 168                           Uday B Garudachar           BJP
# 169                         Ravi Subramanya L A           BJP
# 170                                    R Ashoka           BJP
# 171                             Ramalinga Reddy      Congress
# 172                              C K Ramamurthy           BJP
# 173                                   Manjula S           BJP
# 174                              Satish Reddy M           BJP
# 175                                M Krishnappa           BJP
# 176                                  V Shivanna      Congress
# 177                    Sharath Kumar Bachegowda      Congress
# 178                               K H Muniyappa      Congress
# 179                             Dheeraj Muniraj           BJP
# 180                            Shreenivasaiah N      Congress
# 181                             H C Balakrishna      Congress
# 182                               Iqbal Hussain      Congress
# 183                              D K Shivakumar      Congress
# 184                             H D Kumaraswamy         JD(S)
# 185                           P M Narendraswamy      Congress
# 186                                   Udaya K M      Congress
# 187                         Darshan Puttannaiah  SKP-Congress
# 188                             Ravikumar Gowda      Congress
# 189                 A B Ramesha Bandisiddegowda      Congress
# 190                          N Chaluvarayaswamy      Congress
# 191                                   H T Manju         JD(S)
# 192                             C N Balakrishna         JD(S)
# 193                        K M Shivalinge Gowda      Congress
# 194                                  H K Suresh           BJP
# 195                                 H P Swaroop         JD(S)
# 196                                 H D Revanna         JD(S)
# 197                                     A Manju         JD(S)
# 198                                Cement Manju           BJP
# 199                               Harish Poonja           BJP
# 200                             Umanatha Kotian           BJP
# 201                         Dr Y Bharath Shetty           BJP
# 202                          D Vedavyasa Kamath           BJP
# 203                                   UT Khader      Congress
# 204                               Rajesh Naik U           BJP
# 205                             Ashok Kumar Rai      Congress
# 206                          Bhagirathi Murulya           BJP
# 207                             Dr Mantar Gowda      Congress
# 208                                A S Ponnanna      Congress
# 209                                 K Venkatesh      Congress
# 210                               Ravishankar D      Congress
# 211                            G D Harish Gowda         JD(S)
# 212                            Anil Chikkamadhu      Congress
# 213                      Darshan Dhruvanarayana      Congress
# 214                               G T Devegowda         JD(S)
# 215                               T S Srivathsa           BJP
# 216                              K Harish Gowda      Congress
# 217                                Tanveer Sait      Congress
# 218                                Siddaramaiah      Congress
# 219                          Dr H C Mahadevappa      Congress
# 220                               M R Manjunath         JD(S)
# 221                           A R Krishnamurthy      Congress
# 222                          C Puttarangashetty      Congress
# 223                           H M Ganesh Prasad      Congress

# %%
insert_sql3 = """Insert into MLA_2023(AC_Num, MLA_Name, Party)
        Select CAST("Sl No." as INTEGER), Winners, Party from MLA_2023_temp """

con.execute(insert_sql3)
con.commit()

# %%
pd.reset_option('display.max_rows')
pd.read_sql("Select * from MLA_2023",con)
# Out:
#      AC_Num                       MLA_Name     Party
# 0         1     Jolle Shashikala Annasaheb       BJP
# 1         2         Ganesh Prakash Hukkeri  Congress
# 2         3                  Laxman Savadi  Congress
# 3         4      Bharamgouda Alagouda Kage  Congress
# 4         5  Mahendra Kallappa Tammannavar  Congress
# ..      ...                            ...       ...
# 219     220             Dr H C Mahadevappa  Congress
# 220     221                  M R Manjunath     JD(S)
# 221     222              A R Krishnamurthy  Congress
# 222     223             C Puttarangashetty  Congress
# 223     224              H M Ganesh Prasad  Congress
#
# [224 rows x 3 columns]

# %%
query2="""Drop table if exists MLA_2023_temp"""
con.execute(query2)
con.commit()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table[0])
# Out:
# KA_Constituencies
# MLA_2018
# MLA_2023

# %% [markdown]
# 4. Correcting party names in both tables

# %%
pd.read_sql("SELECT Distinct(party) from MLA_2023",con)
# Out:
#           Party
# 0           BJP
# 1      Congress
# 2         JD(S)
# 3          KRPP
# 4   Independent
# 5  SKP-Congress

# %%
pd.read_sql("SELECT Distinct(party) from MLA_2018",con)
# Out:
#   Party
# 0   BJP
# 1   INC
# 2  None
# 3   JDS

# %%
query3 = "UPDATE MLA_2023 set Party = 'INC' where Party = 'Congress' "

query4 = "UPDATE MLA_2023 set Party = 'JDS' where Party= 'JD(S)' "

query5 = "UPDATE MLA_2018 set Party = 'Independent' where Party IS NULL "

con.execute(query3)
con.execute(query4)
con.execute(query5)
con.commit()

# %%
pd.read_sql("SELECT Distinct(party) from MLA_2023",con)
# Out:
#           Party
# 0           BJP
# 1           INC
# 2           JDS
# 3          KRPP
# 4   Independent
# 5  SKP-Congress

# %%
pd.read_sql("SELECT Distinct(party) from MLA_2018",con)
# Out:
#          Party
# 0          BJP
# 1          INC
# 2  Independent
# 3          JDS

# %% [markdown]
# 5. Correcting MLA names of the same person in both tables

# %%
for i in range(1,225):
        list = con.execute(f"Select MLA_Name, Party from MLA_2018 where AC_Num={i}").fetchall()
        name, par =list[0]

        query6 = (f""" UPDATE MLA_2023
                SET MLA_NAME = '{name}'
                WHERE AC_Num = {i} AND Party = '{par}' """)
        con.execute(query6)
con.commit()

# %% [markdown]
# 6.  Create a new table MLA_KA making union of the above two tables.

# %%
table4 = """
CREATE TABLE MLA_KA (
    'Sl No.' INTEGER PRIMARY KEY,
    MLA_Name TEXT,
    Party TEXT)
"""
con.execute(table4)
con.commit()
pd.read_sql("PRAGMA table_info(MLA_KA)", con)
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0    Sl No.  INTEGER        0       None   1
# 1    1  MLA_Name     TEXT        0       None   0
# 2    2     Party     TEXT        0       None   0

# %%
insert_sql4 = """
INSERT INTO MLA_KA(MLA_Name, Party)
    SELECT MLA_Name, Party FROM MLA_2023
    UNION
    SELECT MLA_Name, Party FROM MLA_2018;
"""
con.execute(insert_sql4)
con.commit()

# %%
pd.read_sql("Select * from MLA_KA",con)
# Out:
#      Sl No.                     MLA_Name Party
# 0         1  A B Ramesha Bandisiddegowda   INC
# 1         2                      A Manju   JDS
# 2         3            A R Krishnamurthy   INC
# 3         4                 A S Ponnanna   INC
# 4         5                 A. Manjunath   JDS
# ..      ...                          ...   ...
# 328     329     Vishweshwar Hegde Kageri   BJP
# 329     330     Vithal Somanna Halagekar   BJP
# 330     331                  Y. V. Patil   INC
# 331     332                 Yathindra S.   INC
# 332     333            Zameer Ahmed Khan   INC
#
# [333 rows x 3 columns]

# %% [markdown]
# 7. Use tables KA_Constituencies, MLA_2018, and MLA_2023. Setting appropriate relationships among these tables, print AC_Num, AC_Name, MLA in 2018, Party, MLA in 2023, and Party.
#  Create table MLA_Rel and insert the above values

# %%
query7 = """ Select a.AC_Num, a.AC_Name,
      b.MLA_Name as MLA_2018, b.Party as Party_2018,
      c.MLA_Name as MLA_2023, c.Party as Party_2023
      from KA_Constituencies as a, MLA_2018 as b, MLA_2023 as c
      where a.AC_Num = b.AC_Num AND a.AC_Num = c.AC_Num """

pd.read_sql(query7,con)
# Out:
#      AC_Num           AC_Name                    MLA_2018 Party_2018  \
# 0         1           Nippani  Shashikala Annasaheb Jolle        BJP
# 1         2  Chikkodi-Sadalga              Ganesh Hukkeri        INC
# 2         3            Athani           Mahesh Kumathalli        BJP
# 3         4            Kagwad               Srimant Patil        BJP
# 4         5           Kudachi                   P. Rajeev        BJP
# ..      ...               ...                         ...        ...
# 219     220      T Narasipura             Ashvin Kumar M.        JDS
# 220     221             Hanur                 R. Narendra        INC
# 221     222          Kollegal                   N. Mahesh        BJP
# 222     223     Chamrajanagar         C. Puttarangashetty        INC
# 223     224         Gundlupet         C.S. Niranjan Kumar        BJP
#
#                           MLA_2023 Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 6 columns]

# %%
table5 = """
CREATE TABLE MLA_Rel (
    'AC_Num' INTEGER PRIMARY KEY,
    'AC_Name' TEXT,
    'MLA_2018' TEXT,
    'Party_2018' TEXT,
    'MLA_2023' TEXT,
    'Party_2023' TEXT)
"""
con.execute(table5)
con.commit()
pd.read_sql("PRAGMA table_info(MLA_Rel)", con)
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0      AC_Num  INTEGER        0       None   1
# 1    1     AC_Name     TEXT        0       None   0
# 2    2    MLA_2018     TEXT        0       None   0
# 3    3  Party_2018     TEXT        0       None   0
# 4    4    MLA_2023     TEXT        0       None   0
# 5    5  Party_2023     TEXT        0       None   0

# %%
insert_sql5 = """
INSERT INTO MLA_Rel(AC_Num, AC_Name, MLA_2018, Party_2018, MLA_2023, Party_2023)
    Select a.AC_Num, a.AC_Name,
      b.MLA_Name as MLA_2018, b.Party as Party_2018,
      c.MLA_Name as MLA_2023, c.Party as Party_2023
      from KA_Constituencies as a, MLA_2018 as b, MLA_2023 as c
      where a.AC_Num = b.AC_Num AND a.AC_Num = c.AC_Num
"""
con.execute(insert_sql5)
con.commit()

# %%
pd.read_sql("Select * from MLA_Rel",con)
# Out:
#      AC_Num           AC_Name                    MLA_2018 Party_2018  \
# 0         1           Nippani  Shashikala Annasaheb Jolle        BJP
# 1         2  Chikkodi-Sadalga              Ganesh Hukkeri        INC
# 2         3            Athani           Mahesh Kumathalli        BJP
# 3         4            Kagwad               Srimant Patil        BJP
# 4         5           Kudachi                   P. Rajeev        BJP
# ..      ...               ...                         ...        ...
# 219     220      T Narasipura             Ashvin Kumar M.        JDS
# 220     221             Hanur                 R. Narendra        INC
# 221     222          Kollegal                   N. Mahesh        BJP
# 222     223     Chamrajanagar         C. Puttarangashetty        INC
# 223     224         Gundlupet         C.S. Niranjan Kumar        BJP
#
#                           MLA_2023 Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 6 columns]

# %% [markdown]
# 8. Use tables KA_Constituencies, MLA_2018, and MLA_2023. Using appropriate JOINs, print AC_Num, AC_Name, MLA in 2018, Party, MLA in 2023, and Party.
# Create table MLA_Join and insert the above values

# %%
query8 = """ Select a.AC_Num, a.AC_Name,
      b.MLA_Name as MLA_2018, b.Party as Party_2018,
      c.MLA_Name as MLA_2023, c.Party as Party_2023
      from KA_Constituencies as a
      JOIN MLA_2018 as b USING(AC_Num)
      JOIN MLA_2023 as c USING(AC_Num) """

pd.read_sql(query8, con)
# Out:
#      AC_Num           AC_Name                    MLA_2018 Party_2018  \
# 0         1           Nippani  Shashikala Annasaheb Jolle        BJP
# 1         2  Chikkodi-Sadalga              Ganesh Hukkeri        INC
# 2         3            Athani           Mahesh Kumathalli        BJP
# 3         4            Kagwad               Srimant Patil        BJP
# 4         5           Kudachi                   P. Rajeev        BJP
# ..      ...               ...                         ...        ...
# 219     220      T Narasipura             Ashvin Kumar M.        JDS
# 220     221             Hanur                 R. Narendra        INC
# 221     222          Kollegal                   N. Mahesh        BJP
# 222     223     Chamrajanagar         C. Puttarangashetty        INC
# 223     224         Gundlupet         C.S. Niranjan Kumar        BJP
#
#                           MLA_2023 Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 6 columns]

# %%
table6 = """
CREATE TABLE MLA_Join (
    'AC_Num' INTEGER PRIMARY KEY,
    'AC_Name' TEXT,
    'MLA_2018' TEXT,
    'Party_2018' TEXT,
    'MLA_2023' TEXT,
    'Party_2023' TEXT)
"""
con.execute(table6)
con.commit()
pd.read_sql("PRAGMA table_info(MLA_Rel)", con)
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0      AC_Num  INTEGER        0       None   1
# 1    1     AC_Name     TEXT        0       None   0
# 2    2    MLA_2018     TEXT        0       None   0
# 3    3  Party_2018     TEXT        0       None   0
# 4    4    MLA_2023     TEXT        0       None   0
# 5    5  Party_2023     TEXT        0       None   0

# %%
insert_sql6 = """
INSERT INTO MLA_Join(AC_Num, AC_Name, MLA_2018, Party_2018, MLA_2023, Party_2023)
    Select a.AC_Num, a.AC_Name,
      b.MLA_Name as MLA_2018, b.Party as Party_2018,
      c.MLA_Name as MLA_2023, c.Party as Party_2023
      from KA_Constituencies as a
      JOIN MLA_2018 as b USING(AC_Num)
      JOIN MLA_2023 as c USING(AC_Num)
"""
con.execute(insert_sql6)
con.commit()

# %%
pd.read_sql("Select * from MLA_Join",con)
# Out:
#      AC_Num           AC_Name                    MLA_2018 Party_2018  \
# 0         1           Nippani  Shashikala Annasaheb Jolle        BJP
# 1         2  Chikkodi-Sadalga              Ganesh Hukkeri        INC
# 2         3            Athani           Mahesh Kumathalli        BJP
# 3         4            Kagwad               Srimant Patil        BJP
# 4         5           Kudachi                   P. Rajeev        BJP
# ..      ...               ...                         ...        ...
# 219     220      T Narasipura             Ashvin Kumar M.        JDS
# 220     221             Hanur                 R. Narendra        INC
# 221     222          Kollegal                   N. Mahesh        BJP
# 222     223     Chamrajanagar         C. Puttarangashetty        INC
# 223     224         Gundlupet         C.S. Niranjan Kumar        BJP
#
#                           MLA_2023 Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 6 columns]

# %% [markdown]
# 9. INNER, LEFT, and RIGHT joins of tables.

# %% [markdown]
# Inner join

# %%
pd.read_sql(""" SELECT a.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a INNER JOIN MLA_2023 b WHERE a.AC_Num = b.AC_Num """, con)
# Out:
#      AC_Num               MLA_2018_Name Party_2018  \
# 0         1  Shashikala Annasaheb Jolle        BJP
# 1         2              Ganesh Hukkeri        INC
# 2         3           Mahesh Kumathalli        BJP
# 3         4               Srimant Patil        BJP
# 4         5                   P. Rajeev        BJP
# ..      ...                         ...        ...
# 219     220             Ashvin Kumar M.        JDS
# 220     221                 R. Narendra        INC
# 221     222                   N. Mahesh        BJP
# 222     223         C. Puttarangashetty        INC
# 223     224         C.S. Niranjan Kumar        BJP
#
#                      MLA_2023_Name Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 5 columns]

# %%
pd.read_sql(""" SELECT a.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a INNER JOIN MLA_2023 b ON a.MLA_Name = b.MLA_Name """, con)
# Out:
#      AC_Num                  MLA_2018_Name Party_2018  \
# 0         1     Shashikala Annasaheb Jolle        BJP
# 1         2                 Ganesh Hukkeri        INC
# 2         6  Duryodhan Mahalingappa Aihole        BJP
# 3         8          Balachandra Jarkiholi        BJP
# 4         9               Ramesh Jarkiholi        BJP
# ..      ...                            ...        ...
# 107     215                   GT Devegowda        JDS
# 108     216                  S. A. Ramadas        BJP
# 109     218                   Tanveer Sait        INC
# 110     219                   Yathindra S.        INC
# 111     223            C. Puttarangashetty        INC
#
#                      MLA_2023_Name Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2    Duryodhan Mahalingappa Aihole        BJP
# 3            Balachandra Jarkiholi        BJP
# 4                 Ramesh Jarkiholi        BJP
# ..                             ...        ...
# 107                   GT Devegowda        JDS
# 108                  S. A. Ramadas        BJP
# 109                   Tanveer Sait        INC
# 110                   Yathindra S.        INC
# 111            C. Puttarangashetty        INC
#
# [112 rows x 5 columns]

# %% [markdown]
# Left join

# %%
pd.read_sql(""" SELECT a.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a LEFT JOIN MLA_2023 b WHERE a.AC_Num = b.AC_Num """, con)
# Out:
#      AC_Num               MLA_2018_Name Party_2018  \
# 0         1  Shashikala Annasaheb Jolle        BJP
# 1         2              Ganesh Hukkeri        INC
# 2         3           Mahesh Kumathalli        BJP
# 3         4               Srimant Patil        BJP
# 4         5                   P. Rajeev        BJP
# ..      ...                         ...        ...
# 219     220             Ashvin Kumar M.        JDS
# 220     221                 R. Narendra        INC
# 221     222                   N. Mahesh        BJP
# 222     223         C. Puttarangashetty        INC
# 223     224         C.S. Niranjan Kumar        BJP
#
#                      MLA_2023_Name Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 5 columns]

# %%
pd.read_sql(""" SELECT a.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a LEFT JOIN MLA_2023 b ON a.MLA_Name = b.MLA_Name """, con)
# Out:
#      AC_Num               MLA_2018_Name Party_2018  \
# 0         1  Shashikala Annasaheb Jolle        BJP
# 1         2              Ganesh Hukkeri        INC
# 2         3           Mahesh Kumathalli        BJP
# 3         4               Srimant Patil        BJP
# 4         5                   P. Rajeev        BJP
# ..      ...                         ...        ...
# 221     220             Ashvin Kumar M.        JDS
# 222     221                 R. Narendra        INC
# 223     222                   N. Mahesh        BJP
# 224     223         C. Puttarangashetty        INC
# 225     224         C.S. Niranjan Kumar        BJP
#
#                   MLA_2023_Name Party_2023
# 0    Shashikala Annasaheb Jolle        BJP
# 1                Ganesh Hukkeri        INC
# 2                          None       None
# 3                          None       None
# 4                          None       None
# ..                          ...        ...
# 221                        None       None
# 222                        None       None
# 223                        None       None
# 224         C. Puttarangashetty        INC
# 225                        None       None
#
# [226 rows x 5 columns]

# %%
pd.read_sql(""" SELECT a.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a RIGHT JOIN MLA_2023 b WHERE a.AC_Num = b.AC_Num """, con)
# Out:
#      AC_Num               MLA_2018_Name Party_2018  \
# 0         1  Shashikala Annasaheb Jolle        BJP
# 1         2              Ganesh Hukkeri        INC
# 2         3           Mahesh Kumathalli        BJP
# 3         4               Srimant Patil        BJP
# 4         5                   P. Rajeev        BJP
# ..      ...                         ...        ...
# 219     220             Ashvin Kumar M.        JDS
# 220     221                 R. Narendra        INC
# 221     222                   N. Mahesh        BJP
# 222     223         C. Puttarangashetty        INC
# 223     224         C.S. Niranjan Kumar        BJP
#
#                      MLA_2023_Name Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2                    Laxman Savadi        INC
# 3        Bharamgouda Alagouda Kage        INC
# 4    Mahendra Kallappa Tammannavar        INC
# ..                             ...        ...
# 219             Dr H C Mahadevappa        INC
# 220                  M R Manjunath        JDS
# 221              A R Krishnamurthy        INC
# 222            C. Puttarangashetty        INC
# 223              H M Ganesh Prasad        INC
#
# [224 rows x 5 columns]

# %%
pd.read_sql(""" SELECT b.AC_Num, a.MLA_Name MLA_2018_Name, a.Party Party_2018, 
            b.MLA_Name MLA_2023_Name, b.Party Party_2023
            FROM MLA_2018 a RIGHT JOIN MLA_2023 b ON a.MLA_Name = b.MLA_Name """, con)
# Out:
#      AC_Num                  MLA_2018_Name Party_2018  \
# 0         1     Shashikala Annasaheb Jolle        BJP
# 1         2                 Ganesh Hukkeri        INC
# 2         6  Duryodhan Mahalingappa Aihole        BJP
# 3         8          Balachandra Jarkiholi        BJP
# 4         9               Ramesh Jarkiholi        BJP
# ..      ...                            ...        ...
# 221     217                           None       None
# 222     220                           None       None
# 223     221                           None       None
# 224     222                           None       None
# 225     224                           None       None
#
#                      MLA_2023_Name Party_2023
# 0       Shashikala Annasaheb Jolle        BJP
# 1                   Ganesh Hukkeri        INC
# 2    Duryodhan Mahalingappa Aihole        BJP
# 3            Balachandra Jarkiholi        BJP
# 4                 Ramesh Jarkiholi        BJP
# ..                             ...        ...
# 221                 K Harish Gowda        INC
# 222             Dr H C Mahadevappa        INC
# 223                  M R Manjunath        JDS
# 224              A R Krishnamurthy        INC
# 225              H M Ganesh Prasad        INC
#
# [226 rows x 5 columns]

# %% [markdown]
# Count, GROUP BY, ORDER BY (not used here)

# %%
query9 = """SELECT Party, COUNT(*) AS MLA_Count FROM MLA_2018 GROUP BY Party;"""

con.execute(query9)
con.commit()
pd.read_sql(query9, con)
# Out:
#          Party  MLA_Count
# 0          BJP        117
# 1          INC         73
# 2  Independent          6
# 3          JDS         28

# %%
query10 = """SELECT Party, COUNT(*) AS MLA_Count, 2018 AS Year
FROM MLA_2018
GROUP BY Party

UNION ALL

SELECT Party, COUNT(*) AS MLA_Count, 2023 AS Year
FROM MLA_2023
GROUP BY Party

ORDER BY Year DESC, MLA_Count DESC;"""
con.execute(query10)
con.commit()
pd.read_sql(query10, con)
# Out:
#           Party  MLA_Count  Year
# 0           INC        135  2023
# 1           BJP         66  2023
# 2           JDS         19  2023
# 3   Independent          2  2023
# 4          KRPP          1  2023
# 5  SKP-Congress          1  2023
# 6           BJP        117  2018
# 7           INC         73  2018
# 8           JDS         28  2018
# 9   Independent          6  2018

# %% [markdown]
# ### Testing

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table[0])
# Out:
# KA_Constituencies
# MLA_2018
# MLA_2023
# MLA_KA
# MLA_Rel
# MLA_Join

# %% [markdown]
# Creating duplicate tables test_KA_constituencies and test_MLA_2018.

# %%
table7 = """(CREATE TABLE test_KA_Constituencies(
    AC_Num INTEGER Primary Key,
    AC_Name Text);)"""

con.execute(table7)
con.commit()
pd.read_sql("PRAGMA table_info(test_KA_Constituencies)", con)
# Out:
#    cid     name     type  notnull dflt_value  pk
# 0    0   AC_Num  INTEGER        0       None   1
# 1    1  AC_Name     TEXT        0       None   0

# %%
insert_sql7 = """(INSERT INTO test_KA_Constituencies
    SELECT * FROM KA_Constituencies;)"""
    
con.execute(insert_sql7)
con.commit()
pd.read_sql("Select * from test_KA_Constituencies",con)
# Out:
#      AC_Num           AC_Name
# 0         1           Nippani
# 1         2  Chikkodi-Sadalga
# 2         3            Athani
# 3         4            Kagwad
# 4         5           Kudachi
# ..      ...               ...
# 219     220      T Narasipura
# 220     221             Hanur
# 221     222          Kollegal
# 222     223     Chamrajanagar
# 223     224         Gundlupet
#
# [224 rows x 2 columns]

# %%
table8 = """ CREATE TABLE test_MLA_2018(
        AC_Num INTEGER Primary Key,
        MLA_Name Text,
        Party Text,
        FOREIGN KEY (AC_Num) REFERENCES test_KA_Constituencies(AC_Num) ON DELETE CASCADE)
      """
con.execute(table8)
con.commit()
pd.read_sql("PRAGMA table_info(test_MLA_2018)", con)
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0    AC_Num  INTEGER        0       None   1
# 1    1  MLA_Name     TEXT        0       None   0
# 2    2     Party     TEXT        0       None   0

# %%
insert_sql8 = """INSERT INTO test_MLA_2018
    SELECT * FROM MLA_2018;"""
    
con.execute(insert_sql8)
con.commit()
pd.read_sql("Select * from test_MLA_2018",con)
# Out:
#      AC_Num                    MLA_Name Party
# 0         1  Shashikala Annasaheb Jolle   BJP
# 1         2              Ganesh Hukkeri   INC
# 2         3           Mahesh Kumathalli   BJP
# 3         4               Srimant Patil   BJP
# 4         5                   P. Rajeev   BJP
# ..      ...                         ...   ...
# 219     220             Ashvin Kumar M.   JDS
# 220     221                 R. Narendra   INC
# 221     222                   N. Mahesh   BJP
# 222     223         C. Puttarangashetty   INC
# 223     224         C.S. Niranjan Kumar   BJP
#
# [224 rows x 3 columns]

# %%
table9 = """ CREATE TABLE test_MLA_2023(
        AC_Num INTEGER,
        MLA_Name Text,
        Party Text,
        FOREIGN KEY (AC_Num) REFERENCES test_KA_Constituencies(AC_Num) ON DELETE SET NULL);
      """
con.execute(table9)
con.commit()
pd.read_sql("PRAGMA table_info(test_MLA_2023)", con)
# Out:
#    cid      name     type  notnull dflt_value  pk
# 0    0    AC_Num  INTEGER        0       None   0
# 1    1  MLA_Name     TEXT        0       None   0
# 2    2     Party     TEXT        0       None   0

# %%
insert_sql9 = """INSERT INTO test_MLA_2023
    SELECT * FROM MLA_2023;"""
    
con.execute(insert_sql9)
con.commit()
pd.read_sql("Select * from test_MLA_2023",con)
# Out:
#      AC_Num                       MLA_Name Party
# 0         1     Shashikala Annasaheb Jolle   BJP
# 1         2                 Ganesh Hukkeri   INC
# 2         3                  Laxman Savadi   INC
# 3         4      Bharamgouda Alagouda Kage   INC
# 4         5  Mahendra Kallappa Tammannavar   INC
# ..      ...                            ...   ...
# 219     220             Dr H C Mahadevappa   INC
# 220     221                  M R Manjunath   JDS
# 221     222              A R Krishnamurthy   INC
# 222     223            C. Puttarangashetty   INC
# 223     224              H M Ganesh Prasad   INC
#
# [224 rows x 3 columns]

# %% [markdown]
# 1. Testing for primary key

# %%
test1 = """INSERT INTO test_KA_Constituencies values(225, 'Hosur')"""
con.execute(test1)
con.commit()

# %%
pd.read_sql("Select * from test_KA_Constituencies",con)
# Out:
#      AC_Num           AC_Name
# 0         1           Nippani
# 1         2  Chikkodi-Sadalga
# 2         3            Athani
# 3         4            Kagwad
# 4         5           Kudachi
# ..      ...               ...
# 220     221             Hanur
# 221     222          Kollegal
# 222     223     Chamrajanagar
# 223     224         Gundlupet
# 224     225             Hosur
#
# [225 rows x 2 columns]

# %%
test2 = """INSERT INTO test_KA_Constituencies values(1, 'Blr')"""
con.execute(test2)
con.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 test2 = """INSERT INTO test_KA_Constituencies values(1, 'Blr')"""
# ----> 2 con.execute(test2)
#       3 con.commit()
#
# IntegrityError: UNIQUE constraint failed: test_KA_Constituencies.AC_Num

# %% [markdown]
# 2. Testing for foreign key

# %%
test3 = """INSERT INTO test_MLA_2018 values(225, 'Reethu', 'Independent')"""
con.execute(test3)
con.commit()
pd.read_sql("Select * from test_MLA_2018",con)
# Out:
#      AC_Num                    MLA_Name        Party
# 0         1  Shashikala Annasaheb Jolle          BJP
# 1         2              Ganesh Hukkeri          INC
# 2         3           Mahesh Kumathalli          BJP
# 3         4               Srimant Patil          BJP
# 4         5                   P. Rajeev          BJP
# ..      ...                         ...          ...
# 220     221                 R. Narendra          INC
# 221     222                   N. Mahesh          BJP
# 222     223         C. Puttarangashetty          INC
# 223     224         C.S. Niranjan Kumar          BJP
# 224     225                      Reethu  Independent
#
# [225 rows x 3 columns]

# %%
test4 = """INSERT INTO test_MLA_2023 values(225, 'Reethu', 'Independent')"""
con.execute(test4)
con.commit()
pd.read_sql("Select * from test_MLA_2023",con)
# Out:
#      AC_Num                       MLA_Name        Party
# 0         1     Shashikala Annasaheb Jolle          BJP
# 1         2                 Ganesh Hukkeri          INC
# 2         3                  Laxman Savadi          INC
# 3         4      Bharamgouda Alagouda Kage          INC
# 4         5  Mahendra Kallappa Tammannavar          INC
# ..      ...                            ...          ...
# 220     221                  M R Manjunath          JDS
# 221     222              A R Krishnamurthy          INC
# 222     223            C. Puttarangashetty          INC
# 223     224              H M Ganesh Prasad          INC
# 224     225                         Reethu  Independent
#
# [225 rows x 3 columns]

# %%
test5 = """INSERT INTO test_MLA_2018 values(450, 'Reethu', 'Independent')"""
con.execute(test5)
con.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 test5 = """INSERT INTO test_MLA_2018 values(450, 'Reethu', 'Independent')"""
# ----> 2 con.execute(test5)
#       3 con.commit()
#
# IntegrityError: FOREIGN KEY constraint failed

# %% [markdown]
# 3. Delete in
# - CASCADE option (test_MLA_2018)
# - SET NULL option (test_MLA_2023)

# %%
delete_query1 = """DELETE FROM test_KA_Constituencies WHERE AC_Num = 225"""
con.execute(delete_query1)
con.commit()

# %%
pd.read_sql("Select * from test_KA_Constituencies",con)
# Out:
#      AC_Num           AC_Name
# 0         1           Nippani
# 1         2  Chikkodi-Sadalga
# 2         3            Athani
# 3         4            Kagwad
# 4         5           Kudachi
# ..      ...               ...
# 219     220      T Narasipura
# 220     221             Hanur
# 221     222          Kollegal
# 222     223     Chamrajanagar
# 223     224         Gundlupet
#
# [224 rows x 2 columns]

# %%
pd.read_sql("Select * from test_MLA_2018",con)
# Out:
#      AC_Num                    MLA_Name Party
# 0         1  Shashikala Annasaheb Jolle   BJP
# 1         2              Ganesh Hukkeri   INC
# 2         3           Mahesh Kumathalli   BJP
# 3         4               Srimant Patil   BJP
# 4         5                   P. Rajeev   BJP
# ..      ...                         ...   ...
# 219     220             Ashvin Kumar M.   JDS
# 220     221                 R. Narendra   INC
# 221     222                   N. Mahesh   BJP
# 222     223         C. Puttarangashetty   INC
# 223     224         C.S. Niranjan Kumar   BJP
#
# [224 rows x 3 columns]

# %%
pd.read_sql("Select * from test_MLA_2023",con)
# Out:
#      AC_Num                       MLA_Name        Party
# 0       1.0     Shashikala Annasaheb Jolle          BJP
# 1       2.0                 Ganesh Hukkeri          INC
# 2       3.0                  Laxman Savadi          INC
# 3       4.0      Bharamgouda Alagouda Kage          INC
# 4       5.0  Mahendra Kallappa Tammannavar          INC
# ..      ...                            ...          ...
# 220   221.0                  M R Manjunath          JDS
# 221   222.0              A R Krishnamurthy          INC
# 222   223.0            C. Puttarangashetty          INC
# 223   224.0              H M Ganesh Prasad          INC
# 224     NaN                         Reethu  Independent
#
# [225 rows x 3 columns]
